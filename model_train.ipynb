# %% [markdown]
# # Fine-tune a DialoGPT model
#
# Adapted from the notebook in [this Medium post](https://towardsdatascience.com/make-your-own-rick-sanchez-bot-with-transformers-and-dialogpt-fine-tuning-f85e6d1f4e30?gi=e4a72d1510f0).

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip -q install transformers

# %%
import os
os.chdir("/content/drive/MyDrive/[Codeology] AvoChat/Demo")

# %%
# all the imports

import glob
import logging
import os
import pickle
import random
import re
import shutil
from typing import Dict, List, Tuple

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler
from torch.utils.data.distributed import DistributedSampler
from tqdm.notebook import tqdm, trange

from pathlib import Path

from transformers import (
    MODEL_WITH_LM_HEAD_MAPPING,
    WEIGHTS_NAME,
    AdamW,
    AutoConfig,
    PreTrainedModel,
    PreTrainedTokenizer,
    get_linear_schedule_with_warmup,
)


try:
    from torch.utils.tensorboard import SummaryWriter
except ImportError:
    from tensorboardX import SummaryWriter

# %%
# !pip show transformers

# %% [markdown]
# ## Data Preprocessing

# %%
# !pwd

# %%
CHARACTER_NAME = "Michael"
data_path = 'data/the-office_lines.csv'
data = pd.read_csv(data_path)
data = data.drop(columns=['Unnamed: 0', 'Season', 'Episode_Number'])
data = data.rename(columns={'Character': 'name', 'Line': 'line'})
data['line'] = data['line'].str.replace(r'\[.*\]', '', regex=True)

# %%
data.sample(6)

# %%
contexted = []

# context window of size 7
n = 3

for i in data[data.name == CHARACTER_NAME].index:
  if i < n:
    continue
  row = []
  prev = i - 1 - n # we additionally substract 1, so row will contain current responce and 7 previous responces
  for j in range(i, prev, -1):
    print('data.line[j]: ', data.line[j])
    row.append(data.line[j])
  contexted.append(row)

columns = ['response', 'context']
columns = columns + ['context/' + str(i) for i in range(n - 1)]

df = pd.DataFrame.from_records(contexted, columns=columns)
# Out:
# Streaming output truncated to the last 5000 lines.
# data.line[j]:   Got it.
# data.line[j]:   Who gave it to you, who has it, and who is going to pay.
# data.line[j]:   I know, I know.
# data.line[j]:   Forget it Michael! Today is about herpes.
# data.line[j]:   I’M TRYING! GOD!
# data.line[j]:   TO answer your question about Jan, no. Jan is insane. Why do you think I got- LEFT, WILLOW NOW!
# data.line[j]:   Got it.
# data.line[j]:   Who gave it to you, who has it, and who is going to pay.
# data.line[j]:    Hi stranger! Long time!
# data.line[j]:   I’M TRYING! GOD!
# data.line[j]:   TO answer your question about Jan, no. Jan is insane. Why do you think I got- LEFT, WILLOW NOW!
# data.line[j]:   Got it.
# data.line[j]:   I’m Michael. We dated for a while.
# data.line[j]:   Who are you?
# data.line[j]:    Hi stranger! Long time!
# data.line[j]:   I’M TRYING! GOD!
# data.line[j]:   Oh hey! Dwight, would you take my grandmother for a walk while I talk to Helene?
# data.line[j]:   Michael?
# data.line[j]:   I don’t think so…
# data.line[j]:   I’m Michael. We dated for a while.
# data.line[j]:   Did I make more of what we had then what was really there?
# data.line[j]:   It’ll go away in time just don’t touch it.
# data.line[j]:   Well did you h- di- GAH! Does no one appreciate what I’m doing right now?!
# data.line[j]:   I didn’t want you it!
# data.line[j]:   Just a quirky indie movie weird sort of thing, breaking all the rules. But had to end, because the summer was over. For you…
# data.line[j]:   What did you think we were?
# data.line[j]:   Did I make more of what we had then what was really there?
# data.line[j]:   It’ll go away in time just don’t touch it.
# data.line[j]:   Jerk.
# data.line[j]:   I think for you to have come here even expecting that we can have a conversation like this show’s ho-how self deluded you are! Michael, your memory has failed you greatly.
# data.line[j]:   Just a quirky indie movie weird sort of thing, breaking all the rules. But had to end, because the summer was over. For you…
# data.line[j]:   What did you think we were?
# data.line[j]:   Real entertainers, like Billy Joel.
# data.line[j]:   So this is the chef’s kitchen, which makes it perfect for real entertainers.
# data.line[j]:   Michael!
# data.line[j]:   Jerk.
# data.line[j]:   Carroll, how are you?
# data.line[j]:   Michael.
# data.line[j]:   Real entertainers, like Billy Joel.
# data.line[j]:   So this is the chef’s kitchen, which makes it perfect for real entertainers.
# data.line[j]:   I’m great! I saw your-your sign outside. And I decided, I’m going to pull in, and maybe buy a house from her.
# data.line[j]:   I’m great! How are you?
# data.line[j]:   Carroll, how are you?
# data.line[j]:   Michael.
# data.line[j]:   No.
# data.line[j]:   You didn’t call my office and ask where I was?
# data.line[j]:   I’m great! I saw your-your sign outside. And I decided, I’m going to pull in, and maybe buy a house from her.
# data.line[j]:   I’m great! How are you?
# data.line[j]:   Weird…
# data.line[j]:   Because the receptionist told me a man called but he only said he was my ex-lover.
# data.line[j]:   No.
# data.line[j]:   You didn’t call my office and ask where I was?
# data.line[j]:   He sounds like a nice guy.
# data.line[j]:   Yeah.
# data.line[j]:   Weird…
# data.line[j]:   Because the receptionist told me a man called but he only said he was my ex-lover.
# data.line[j]:   Oh wow another living room!
# data.line[j]:   I’ll let this slide, but I expect you to put this whole Erin thing behind you.
# data.line[j]:   The only reason I said that is because you asked me so politely! It was very difficult for me to say no.
# data.line[j]:   I asked you if it was ok if I asked her out. You said, and I quote, ‘My good sir! Nothing would make me happier than to hand you the hand of the hand once in my hand.’ I specifically remember it because you said it in such a weird way.
# data.line[j]:   You put the TV here, you put the family over here.
# data.line[j]:   It’s a family room.
# data.line[j]:   Oh wow another living room!
# data.line[j]:   I’ll let this slide, but I expect you to put this whole Erin thing behind you.
# data.line[j]:   Someone told me that I romanticize relationships
# data.line[j]:   Michael why are you here?
# data.line[j]:   You put the TV here, you put the family over here.
# data.line[j]:   It’s a family room.
# data.line[j]:   I have herpes.
# data.line[j]:   You know, we all do that.
# data.line[j]:   Someone told me that I romanticize relationships
# data.line[j]:   Michael why are you here?
# data.line[j]:   I just found out today. It’s, uh, right there.
# data.line[j]:   What? Did you have that while we were together?
# data.line[j]:   I have herpes.
# data.line[j]:   You know, we all do that.
# data.line[j]:   Mmhmm, I’m sorry.
# data.line[j]:   Oh! Oh, that’s what you’re talking about?
# data.line[j]:   I just found out today. It’s, uh, right there.
# data.line[j]:   What? Did you have that while we were together?
# data.line[j]:   I’m between specialists right now.
# data.line[j]:   Did the doctor check it out?
# data.line[j]:   Mmhmm, I’m sorry.
# data.line[j]:   Oh! Oh, that’s what you’re talking about?
# data.line[j]:   Well I believe in love at first sight.
# data.line[j]:   Yes, yes Michael. Actually you do make a bigger deal out of things than you need to. You proposed to me on our fourth date.
# data.line[j]:   I’m between specialists right now.
# data.line[j]:   Did the doctor check it out?
# data.line[j]:   I knew what I was thinking at the time, but right now it just seems ridiculous.
# data.line[j]:   Well so do I, but we didn’t love each other at first either. I don’t know what you were thinking!
# data.line[j]:   Well I believe in love at first sight.
# data.line[j]:   Yes, yes Michael. Actually you do make a bigger deal out of things than you need to. You proposed to me on our fourth date.
# data.line[j]:   Hi Holly it’s Michael, I just wanted to call and let you know that I was thinking about what you said. It’s just. You know?  It’s weird. Today I ended up seeing a lot of women that I used to date, and in my mind they were all great. And then when I actually saw them, it was mostly a freak show. And you and me, that must have been a real train wreck. You know what, Holly? You’re wrong. You are wrong. I remember every second of us. And talking to them today, I don’t feel for them anything like what I feel for you. I didn’t joke with any of them, I joked with you. You are the only one who was actually happy to hear from me. And I don’t know why you downgraded what we had but I did not make us up. Ok.  Oh, wait, and you should talk to a doctor because you might have herpes. Bye.
# data.line[j]:
# data.line[j]:   I have no idea what his problem is, that’s just my standard advice. It’s good advice right?
# data.line[j]:   Yeah.
# data.line[j]:   Oscar, we once sucked face in public. As part of an office presentation to destroy the stigma of gay kissing. Do you recall?
# data.line[j]:   What is this about?
# data.line[j]:   Hi Holly it’s Michael, I just wanted to call and let you know that I was thinking about what you said. It’s just. You know?  It’s weird. Today I ended up seeing a lot of women that I used to date, and in my mind they were all great. And then when I actually saw them, it was mostly a freak show. And you and me, that must have been a real train wreck. You know what, Holly? You’re wrong. You are wrong. I remember every second of us. And talking to them today, I don’t feel for them anything like what I feel for you. I didn’t joke with any of them, I joked with you. You are the only one who was actually happy to hear from me. And I don’t know why you downgraded what we had but I did not make us up. Ok.  Oh, wait, and you should talk to a doctor because you might have herpes. Bye.
# data.line[j]:
# data.line[j]:   You may have given me a sexually transmitted disease.
# data.line[j]:   Yes!
# data.line[j]:   Oscar, we once sucked face in public. As part of an office presentation to destroy the stigma of gay kissing. Do you recall?
# data.line[j]:   What is this about?
# data.line[j]:   Herpes duplex.
# data.line[j]:   What?
# data.line[j]:   You may have given me a sexually transmitted disease.
# data.line[j]:   Yes!
# data.line[j]:   I have already contacted all of my ex-lovers except for you.
# data.line[j]:   It was probably just an ingrown mustache hair but we have to be exhaustive.
# data.line[j]:   Herpes duplex.
# data.line[j]:   What?
# data.line[j]:   Flower shops, fireworks celebrations…
# data.line[j]:   I’m gonna need a list of every man you’ve ever had sex with. I’m talking train stations, men’s rooms…
# data.line[j]:   We were never lovers!
# data.line[j]:   I have already contacted all of my ex-lovers except for you.
# data.line[j]:   Moolit Gandala, carrage drive through Central Park…
# data.line[j]:   Fence with a hole in it..
# data.line[j]:   Flower shops, fireworks celebrations…
# data.line[j]:   I’m gonna need a list of every man you’ve ever had sex with. I’m talking train stations, men’s rooms…
# data.line[j]:   An electric car dealership.
# data.line[j]:   The woods behind the liquor store, the swamp behind the old folk’s home.
# data.line[j]:   Moolit Gandala, carrage drive through Central Park…
# data.line[j]:   Fence with a hole in it..
# data.line[j]:   Oscar! Think abou- Think!
# data.line[j]:   The democratic primaries,
# data.line[j]:   An electric car dealership.
# data.line[j]:   The woods behind the liquor store, the swamp behind the old folk’s home.
# data.line[j]:   Nice!
# data.line[j]:   Oscar! Think abou- Think!
# data.line[j]:   The democratic primaries,
# data.line[j]:   An electric car dealership.
# data.line[j]:   She is a beaut!
# data.line[j]:   Okay.
# data.line[j]:   I love cycling. Andy, I feel like a tourist in my own city. I literally can’t wait to wake up every morning.
# data.line[j]:   Nice!
# data.line[j]:   Oh, look at that.   Smooth roll.
# data.line[j]:   Yes, it is.
# data.line[j]:   Can’t beat a horse. A horse is a bike that peddles itself.
# data.line[j]:   She is a beaut!
# data.line[j]:   Oh, god!
# data.line[j]:    Michael!
# data.line[j]:   I’m on Sheryl Crow’s side in that whole thing, so I feel really weird right now.
# data.line[j]:   No, Meredith, that’s not his actual bicycle, but it is the same exact model he uses.
# data.line[j]:   Yes, I can ride a bike. I take spinning classes three times a month. I think I know how to ride a bike.
# data.line[j]:   Oh…
# data.line[j]:   Oh, god!
# data.line[j]:    Michael!
# data.line[j]:   I did, yes! I had those extra wheels on the back…that support you.  Mi-chael! Mi-chael!
# data.line[j]:   Are you sure you once knew how to do this?
# data.line[j]:   Yes, I can ride a bike. I take spinning classes three times a month. I think I know how to ride a bike.
# data.line[j]:   Oh…
# data.line[j]:    Oh, my god!
# data.line[j]:   Just steer more now.
# data.line[j]:   Come on, Michael! Yeah!
# data.line[j]:   Yeah!
# data.line[j]:   Ow!  You never forget. Whoo!
# data.line[j]:   No! No!
# data.line[j]:   Not the car!
# data.line[j]:    Oh, my god!
# data.line[j]:   Brainstorming session is now open. Anyone has an idea- Hold on. Sorry, sorry, sorry. Hello?
# data.line[j]:   He’s not just here for the coffee, Jim. Wake up!
# data.line[j]:   Dwight!
# data.line[j]:   Like hell you are.
# data.line[j]:   Oh, hey. No, I’m not busy. What’s up?
# data.line[j]:   Hey, it’s Jim. Listen, this is important. Are you busy?
# data.line[j]:   Brainstorming session is now open. Anyone has an idea- Hold on. Sorry, sorry, sorry. Hello?
# data.line[j]:   He’s not just here for the coffee, Jim. Wake up!
# data.line[j]:   It’s Jim, Okay? Yes.
# data.line[j]:   You are busy! We’re in a meeting!
# data.line[j]:   What?
# data.line[j]:   Oh, hey. No, I’m not busy. What’s up?
# data.line[j]:   You need the big guns, yes?
# data.line[j]:   Listen, you gotta get over here, ’cause we’re pitching Steve Nash and Danny Cordray is here.
# data.line[j]:   It’s Jim, Okay? Yes.
# data.line[j]:   You are busy! We’re in a meeting!
# data.line[j]:   I will see you in ten. Bye! Hold tight.  Well, I know a lot of you thought that my sales days were behind me, and to be honest, so did I…and the only reason I got out of the sales game was to be reluctantly called back in.
# data.line[j]:   The big gun thing.  Stop!
# data.line[j]:   What’d he say? What did he say?
# data.line[j]:   Yes.
# data.line[j]:    No, I don’t have time for this. Are you kidding me?
# data.line[j]:   You don’t look reluctant, Michael. You look really eager.
# data.line[j]:   I will see you in ten. Bye! Hold tight.  Well, I know a lot of you thought that my sales days were behind me, and to be honest, so did I…and the only reason I got out of the sales game was to be reluctantly called back in.
# data.line[j]:   The big gun thing.  Stop!
# data.line[j]:   No! Okay.  All right.
# data.line[j]:   You don’t?
# data.line[j]:    No, I don’t have time for this. Are you kidding me?
# data.line[j]:   You don’t look reluctant, Michael. You look really eager.
# data.line[j]:   Oh, no, that’s a male model.
# data.line[j]:   There he is.
# data.line[j]:   Yes!
# data.line[j]:   That’s crazy money. I’ll take forty.
# data.line[j]:   That…hello. Michael Scott, Dunder-Mifflin Paper Company.
# data.line[j]:   No, that’s him.
# data.line[j]:   Oh, no, that’s a male model.
# data.line[j]:   There he is.
# data.line[j]:   Nice to meet you.
# data.line[j]:   Danny Cordray, Osprey Paper.
# data.line[j]:   That…hello. Michael Scott, Dunder-Mifflin Paper Company.
# data.line[j]:   No, that’s him.
# data.line[j]:   Yeah, well…we call it overkill. Why am I telling you my strategy?
# data.line[j]:   Three of you guys for one sale.
# data.line[j]:   Nice to meet you.
# data.line[j]:   Danny Cordray, Osprey Paper.
# data.line[j]:   All right.
# data.line[j]:   Well, whatever works for ya. Anyway. All right.
# data.line[j]:   Yeah, well…we call it overkill. Why am I telling you my strategy?
# data.line[j]:   Three of you guys for one sale.
# data.line[j]:   Buh-bye. I could swear that guy was a male model.
# data.line[j]:   It’s good to see you guys. Nice to meet you.
# data.line[j]:   All right.
# data.line[j]:   Well, whatever works for ya. Anyway. All right.
# data.line[j]:   Oh, thank you. All right. On the count of three, it’s showtime. Ready, one, two–
# data.line[j]:   He’s ready for you.
# data.line[j]:   Buh-bye. I could swear that guy was a male model.
# data.line[j]:   It’s good to see you guys. Nice to meet you.
# data.line[j]:   Okay, you know-all right, just forget it then.
# data.line[j]:   I’ve been in showtime mode since breakfast.
# data.line[j]:   Nope, not doing that.
# data.line[j]:   Oh, thank you. All right. On the count of three, it’s showtime. Ready, one, two–
# data.line[j]:   It’s showtime! Oh…never mind. Let’s go.
# data.line[j]:   Showtime!
# data.line[j]:   Okay, you know-all right, just forget it then.
# data.line[j]:   I’ve been in showtime mode since breakfast.
# data.line[j]:   When I knock on your door, you know who it is; it’s Michael Scott. We’ve been together forever and we-
# data.line[j]:   It’s showtime! Oh…never mind. Let’s go.
# data.line[j]:   Showtime!
# data.line[j]:   Okay, you know-all right, just forget it then.
# data.line[j]:   You know what? You are having some problems with your loading dock, are you not? All right. We’re going to deliver to you on weekends.
# data.line[j]:   Michael, I appreciate everything that Dunder-Mifflin has done for this company.
# data.line[j]:   When I knock on your door, you know who it is; it’s Michael Scott. We’ve been together forever and we-
# data.line[j]:   It’s showtime! Oh…never mind. Let’s go.
# data.line[j]:   And you know what else we’re gonna do? I can’t believe I’m gonna say this…we are going to offer you our paper at cost. I know. I could get in a lotta trouble for this, so you’d better shake my hand right now.
# data.line[j]:   That’s very generous, but-
# data.line[j]:   You know what? You are having some problems with your loading dock, are you not? All right. We’re going to deliver to you on weekends.
# data.line[j]:   Michael, I appreciate everything that Dunder-Mifflin has done for this company.
# data.line[j]:   Shake it, shake it!
# data.line[j]:   He’s not kidding.
# data.line[j]:   And you know what else we’re gonna do? I can’t believe I’m gonna say this…we are going to offer you our paper at cost. I know. I could get in a lotta trouble for this, so you’d better shake my hand right now.
# data.line[j]:   That’s very generous, but-
# data.line[j]:   Okay. Thank you.
# data.line[j]:   Thanks for coming in.
# data.line[j]:   Oh.
# data.line[j]:   Michael, I’m going with Danny.
# data.line[j]:   Thanks, Steve.
# data.line[j]:   Thank you.
# data.line[j]:   Okay. Thank you.
# data.line[j]:   Thanks for coming in.
# data.line[j]:   Stop it. Just stop it. We did what we should have done, we just got bested.  Why is there a door close button if it doesn’t even close the door?
# data.line[j]:   Yes, you did.
# data.line[j]:   No, I didn’t.
# data.line[j]:   Jim talked too much.
# data.line[j]:   How do I feel about losing the sale? It’s like if Michael Phelps came out of retirement, jumped in the pool, belly-flopped, and drowned.
# data.line[j]:   Stop it. Just stop it. We did what we should have done, we just got bested.  Why is there a door close button if it doesn’t even close the door?
# data.line[j]:   Yes, you did.
# data.line[j]:   No, I didn’t.
# data.line[j]:   You know who we always lose out to? Staples, the big guys. Osprey? They’re a small company. They’re smaller than we are. What’s our excuse? How do we combat this guy? Stanley, how do we combat him?
# data.line[j]:   How do I feel about losing the sale? It’s like if Michael Phelps came out of retirement, jumped in the pool, belly-flopped, and drowned.
# data.line[j]:   Stop it. Just stop it. We did what we should have done, we just got bested.  Why is there a door close button if it doesn’t even close the door?
# data.line[j]:   Yes, you did.
# data.line[j]:   Okay. You know what? You clearly don’t care, so why don’t you just leave?
# data.line[j]:   We sell better?
# data.line[j]:   You know who we always lose out to? Staples, the big guys. Osprey? They’re a small company. They’re smaller than we are. What’s our excuse? How do we combat this guy? Stanley, how do we combat him?
# data.line[j]:   How do I feel about losing the sale? It’s like if Michael Phelps came out of retirement, jumped in the pool, belly-flopped, and drowned.
# data.line[j]:   Why don’t you go outside and…take a shot of insulin and have a nap, okay?
# data.line[j]:   I would like to stay. This pertains to me.
# data.line[j]:   Okay. You know what? You clearly don’t care, so why don’t you just leave?
# data.line[j]:   We sell better?
# data.line[j]:   I don’t know, your frame, your build-why don’t you have a glass of apple juice and tell me you’re not a diabetic.  See? I could tell by the sound you made when you stood up that you have-okay. Yes, Phyllis?
# data.line[j]:   Why do you always assume I have diabetes?
# data.line[j]:   Why don’t you go outside and…take a shot of insulin and have a nap, okay?
# data.line[j]:   I would like to stay. This pertains to me.
# data.line[j]:   Oh, my god!
# data.line[j]:   I could try to seduce him.
# data.line[j]:   I don’t know, your frame, your build-why don’t you have a glass of apple juice and tell me you’re not a diabetic.  See? I could tell by the sound you made when you stood up that you have-okay. Yes, Phyllis?
# data.line[j]:   Why do you always assume I have diabetes?
# data.line[j]:   You know what this is? This is a stinger.
# data.line[j]:   This is weird.
# data.line[j]:   I’m outta here.
# data.line[j]:   Uh…
# data.line[j]:   Like the movie.
# data.line[j]:   A what?
# data.line[j]:   You know what this is? This is a stinger.
# data.line[j]:   This is weird.
# data.line[j]:   Paul Newman, Robert Redford. They’re bank robbers.
# data.line[j]:   I think you mean The Sting.
# data.line[j]:   Like the movie.
# data.line[j]:   A what?
# data.line[j]:   Shhh! Hey! That’s my mug.
# data.line[j]:   Okay. But what is he more famous for?
# data.line[j]:   Van Helsing was a respected professor before he was a vampire killer.
# data.line[j]:   Meredith Van Helsing?
# data.line[j]:   Yes.
# data.line[j]:   You know this isn’t real TV, right?
# data.line[j]:   Shhh! Hey! That’s my mug.
# data.line[j]:   Okay. But what is he more famous for?
# data.line[j]:   Oh, no, no. No. Don’t-
# data.line[j]:   Hel-lo!
# data.line[j]:   I’m gonna take off my coat, if you don’t mind. It’s a bit warm in here.
# data.line[j]:   Okay, three-way argument between a drummer, a keyboardist, and the front man lead singer. Wonder who’s gonna win this one. Two, three, four-
# data.line[j]:   Testify.
# data.line[j]:   People can’t keep their true natures hidden for long, and this guy is smoldering like a tire fire.
# data.line[j]:   Oh, no, no. No. Don’t-
# data.line[j]:   Hel-lo!
# data.line[j]:   Yeah, he is that good-looking.
# data.line[j]:   Okay, he’s not that good-looking. I don’t understand why everybody’s obsessed with this-
# data.line[j]:   Testify.
# data.line[j]:   People can’t keep their true natures hidden for long, and this guy is smoldering like a tire fire.
# data.line[j]:   Okay.
# data.line[j]:   He’s very, very handsome.
# data.line[j]:   Yeah, he is that good-looking.
# data.line[j]:   Okay, he’s not that good-looking. I don’t understand why everybody’s obsessed with this-
# data.line[j]:   Pull it together, all right? Stop lookin’ at him.
# data.line[j]:   That’s a great set of shoulder’s you got there. What is that…Genetics? Creatine?  Sorry. Yeah?
# data.line[j]:   Okay.
# data.line[j]:   He’s very, very handsome.
# data.line[j]:   Oh…my god! He’s making her sell to him.
# data.line[j]:   What do you mean?
# data.line[j]:   Well, actually, uh… no, Miss Van Helsing, that’s not why I’m here. I’m here to meet you, see if we’d be a, you know, good fit.
# data.line[j]:   I’m sorry.  You’re here to sell me some paper.
# data.line[j]:   Stay-
# data.line[j]:   Ha ha, okay, there you go!
# data.line[j]:   Real well. Uh…feels more like a third date to me.
# data.line[j]:   We should think of this as a first date. And I think it’s going very well, how ’bout you?
# data.line[j]:   Oh!
# data.line[j]:   Well, we’ll get this…
# data.line[j]:   Oh…
# data.line[j]:   I’ve never been a desk man. Always traveling on the road. Come on…why not, huh?
# data.line[j]:   Don’t let us down.
# data.line[j]:   Great. Sounds awesome. Just have him pitch to you.
# data.line[j]:   Okay. Stark Industries isn’t real. I run Google. Larry and Sergey brought me in-
# data.line[j]:   Okay. You’re a young hotshot from Stark Industries. You’ve just bought this company. Meredith is fired. It’s a whole new regime. He’s gotta pitch to you now.
# data.line[j]:   No, no, no….
# data.line[j]:   Danny, I feel a real connection to you, and I gotta get real, I’m-
# data.line[j]:   You know what? I may have parked my car in a compact space, and I hate when I see others do that, so-
# data.line[j]:   You smell like a Scorpio.  This is…Esteban…another cleaning man. He doesn’t speak English either. Esteban, el flooro.
# data.line[j]:   I’m goin ‘in!
# data.line[j]:   No, no, no, no…
# data.line[j]:   No, no, no….
# data.line[j]:   Danny, I feel a real connection to you, and I gotta get real, I’m-
# data.line[j]:   Stop, stop! Oh, my god!  Okay. Stop it, stop it, stop it. Gross! Stop it, please. Everybody, stop.
# data.line[j]:   Michael! No, Michael, stop it! No!
# data.line[j]:   I’m goin ‘in!
# data.line[j]:   No, no, no, no…
# data.line[j]:   I said stop. Okay, Danny…this is not Pennsylvania Solartech. This is Dunder-Mifflin Paper Company. This is Meredith Palmer-
# data.line[j]:   Michael Scott.
# data.line[j]:   Stop, stop! Oh, my god!  Okay. Stop it, stop it, stop it. Gross! Stop it, please. Everybody, stop.
# data.line[j]:   Michael! No, Michael, stop it! No!
# data.line[j]:   Don’t! Get away from him. Please, just leave. Get out of here. Go. Forever.
# data.line[j]:   Please to meet you-
# data.line[j]:   I said stop. Okay, Danny…this is not Pennsylvania Solartech. This is Dunder-Mifflin Paper Company. This is Meredith Palmer-
# data.line[j]:   Michael Scott.
# data.line[j]:   I owe you…a most sincere and humble apology. We were trying to watch you to see your sales technique, so we could stop losing so many clients to you.
# data.line[j]:   Hmm.
# data.line[j]:   Don’t! Get away from him. Please, just leave. Get out of here. Go. Forever.
# data.line[j]:   Please to meet you-
# data.line[j]:   A surveillance room next to this one.
# data.line[j]:   But from where?
# data.line[j]:   I owe you…a most sincere and humble apology. We were trying to watch you to see your sales technique, so we could stop losing so many clients to you.
# data.line[j]:   Hmm.
# data.line[j]:   Yes. And it’s the sincerest form of flattery.
# data.line[j]:   Okay, so you…set up this fake company, then you hired this homeless woman to impersonate an executive to spy on me so that you could copy my sales technique?
# data.line[j]:   A surveillance room next to this one.
# data.line[j]:   But from where?
# data.line[j]:   Well-
# data.line[j]:   Or…crazy.
# data.line[j]:   Yes. And it’s the sincerest form of flattery.
# data.line[j]:   Okay, so you…set up this fake company, then you hired this homeless woman to impersonate an executive to spy on me so that you could copy my sales technique?
# data.line[j]:   Okay. You know what, it wasn’t just me. Jim and Dwight are behind that wall in the surveillance room and it was their plan as well.
# data.line[j]:   I’m gonna go.
# data.line[j]:   Well-
# data.line[j]:   Or…crazy.
# data.line[j]:   No, we don’t. Here’s-here’s my point. Danny, listen, you have to understand that we are not normally like this. We just-we wanted to know your tricks.
# data.line[j]:   Oh, well then, yeah. All right. Hey!  Good luck, guys. Seems like you got a great operation here.
# data.line[j]:   No, no, no, no.
# data.line[j]:   No!
# data.line[j]:   You are, you are. You are! Stop it, stop it. Stop.  You are a good salesman. And because of that…I want you to work for me.
# data.line[j]:   What do you mean, my tricks? There’s no tricks, man. I’m just a good salesman. You wanna copy that? You can’t copy that!
# data.line[j]:   No, we don’t. Here’s-here’s my point. Danny, listen, you have to understand that we are not normally like this. We just-we wanted to know your tricks.
# data.line[j]:   Oh, well then, yeah. All right. Hey!  Good luck, guys. Seems like you got a great operation here.
# data.line[j]:   So, you will?
# data.line[j]:   Sure. You seem like a fun, professional guy.
# data.line[j]:   You are, you are. You are! Stop it, stop it. Stop.  You are a good salesman. And because of that…I want you to work for me.
# data.line[j]:   What do you mean, my tricks? There’s no tricks, man. I’m just a good salesman. You wanna copy that? You can’t copy that!
# data.line[j]:   Hold it, hold it.  Hold on, hold on. Wait, wait, wait, wait. Wait. Wait. Danny, I want you to look at me. Do you want your life to be better…or to be worse or to stay the same?
# data.line[j]:    No!
# data.line[j]:   So, you will?
# data.line[j]:   Sure. You seem like a fun, professional guy.
# data.line[j]:   Answer the question. Do you want a better life, Danny?
# data.line[j]:   Get out of my way.
# data.line[j]:   Hold it, hold it.  Hold on, hold on. Wait, wait, wait, wait. Wait. Wait. Danny, I want you to look at me. Do you want your life to be better…or to be worse or to stay the same?
# data.line[j]:    No!
# data.line[j]:   I know, I know.
# data.line[j]:   I swear to God, I’m gonna hit you. I didn’t mean that. I’m sorry. I’m not-it’s just I’m very upset right now.
# data.line[j]:   Answer the question. Do you want a better life, Danny?
# data.line[j]:   Get out of my way.
# data.line[j]:   Do you want more freedom, less freedom, or to stay the same?
# data.line[j]:   I’m very upset!
# data.line[j]:   I know, I know.
# data.line[j]:   I swear to God, I’m gonna hit you. I didn’t mean that. I’m sorry. I’m not-it’s just I’m very upset right now.
# data.line[j]:   I can give you more money-there’s your better life. I can let you come and go as you please-there’s your freedom. And you already know Dunder-Mifflin has the best service and the best prices, but you beat us anyway. Can you imagine how well you would do selling our stuff?
# data.line[j]:   More freedom.
# data.line[j]:   Do you want more freedom, less freedom, or to stay the same?
# data.line[j]:   I’m very upset!
# data.line[j]:   Everyone, may I have your attention? I would like to introduce you to Mr. Danny Cordray. He is going to be joining us as our new traveling salesman. Say hello to Danny!
# data.line[j]:   I can give you more money-there’s your better life. I can let you come and go as you please-there’s your freedom. And you already know Dunder-Mifflin has the best service and the best prices, but you beat us anyway. Can you imagine how well you would do selling our stuff?
# data.line[j]:   More freedom.
# data.line[j]:   Do you want more freedom, less freedom, or to stay the same?
# data.line[j]:   O-kay. You know what? No. No. This is not some sort of construction site…or all of Italy, where you can just go around treating people like meat. We are to respect him. I respect him because he reminds me of somebody. Can anybody guess who that is?
# data.line[j]:    me!
# data.line[j]:   Everyone, may I have your attention? I would like to introduce you to Mr. Danny Cordray. He is going to be joining us as our new traveling salesman. Say hello to Danny!
# data.line[j]:   I can give you more money-there’s your better life. I can let you come and go as you please-there’s your freedom. And you already know Dunder-Mifflin has the best service and the best prices, but you beat us anyway. Can you imagine how well you would do selling our stuff?
# data.line[j]:   No. No. No. Somebody in this office.
# data.line[j]:   Yeah, I can see that.
# data.line[j]:   Josh Duhamel.
# data.line[j]:   O-kay. You know what? No. No. This is not some sort of construction site…or all of Italy, where you can just go around treating people like meat. We are to respect him. I respect him because he reminds me of somebody. Can anybody guess who that is?
# data.line[j]:   No, me. Right? Sorta like…a little younger version of me.
# data.line[j]:   Thanks, Kevin.
# data.line[j]:   He’s like a better-looking Andy.
# data.line[j]:   No. No. No. Somebody in this office.
# data.line[j]:   Yes.
# data.line[j]:   Michael?
# data.line[j]:   It’s hard to judge ourselves accurately, isn’t it.
# data.line[j]:   No, me. Right? Sorta like…a little younger version of me.
# data.line[j]:   No, you may not.
# data.line[j]:   Can I talk to you about something?
# data.line[j]:   Yes.
# data.line[j]:   Michael?
# data.line[j]:   I said no.
# data.line[j]:   It’s about this very announcement you just made.
# data.line[j]:   No, you may not.
# data.line[j]:   Can I talk to you about something?
# data.line[j]:   We’re not-
# data.line[j]:   Michael-
# data.line[j]:   I said no.
# data.line[j]:   It’s about this very announcement you just made.
# data.line[j]:   Okay. Let’s-all right, all right. Let’s talk. Please don’t let him leave.  Don’t leave. Don’t let him.
# data.line[j]:   Michael, I think you really want to talk to him.
# data.line[j]:   We’re not-
# data.line[j]:   Michael-
# data.line[j]:   Guys, let me ask you something. Do you want your life to be better or worse or stay the same?
# data.line[j]:   You hired him?
# data.line[j]:   Gotcha.
# data.line[j]:   Okay. Let’s-all right, all right. Let’s talk. Please don’t let him leave.  Don’t leave. Don’t let him.
# data.line[j]:   Okay. Well…get ready, ’cause it’s gonna get better.
# data.line[j]:   Stay the same.
# data.line[j]:   Guys, let me ask you something. Do you want your life to be better or worse or stay the same?
# data.line[j]:   You hired him?
# data.line[j]:   No, no. Wrong. He would have stolen your clients, but you know what? He can’t now. This guy used to steal sales from us; now, he’s going to steal sales for us.
# data.line[j]:   It’s not gonna get better; he’s gonna steal all of our clients.
# data.line[j]:   Okay. Well…get ready, ’cause it’s gonna get better.
# data.line[j]:   Stay the same.
# data.line[j]:   He doesn’t need to sit, he’s a traveling salesman. Look, I am not going to exclude good people from our staff simply because they are threatening to you. And unless you have a better argument than that, I suggest you leave.
# data.line[j]:   Where’s he gonna sit? There’s no more seats.
# data.line[j]:   No, no. Wrong. He would have stolen your clients, but you know what? He can’t now. This guy used to steal sales from us; now, he’s going to steal sales for us.
# data.line[j]:   It’s not gonna get better; he’s gonna steal all of our clients.
# data.line[j]:   Good-bye!
# data.line[j]:   Where’s he gonna park? There’s no more reserved parking spots.
# data.line[j]:   Hmpf!
# data.line[j]:   He doesn’t need to sit, he’s a traveling salesman. Look, I am not going to exclude good people from our staff simply because they are threatening to you. And unless you have a better argument than that, I suggest you leave.
# data.line[j]:   This morning, Danny Cordray stole a sale from me. So what do I do? I go out and I steal Danny Cordray. The sale that mattered, I made. Boom. Funny thing about it, we don’t even need him. We already have Packer on the road. Chhguuh! Crap. I forgot about Packer.
# data.line[j]:   Thanks.
# data.line[j]:   Pleasure.
# data.line[j]:   Oh.
# data.line[j]:    All right, everybody, take a seat. As you may have heard, our branch on the planet Jupiter is up eight thousand percent in sales!
# data.line[j]:   Shh! Shhh!
# data.line[j]:   Hmmm.  Thank you.
# data.line[j]:    Handbag.
# data.line[j]:   A lot of people are really getting into Halloween this year!  MACGRUBERRRR!
# data.line[j]:   Dunder Mifflin, this is Erin! Happy Halloween! How can I haunt you today?
# data.line[j]:   The statement that I am making, Oscar, is that I kind of look like Michael Moore.
# data.line[j]:   So what kind of statement are you making with that costume, Kevin?
# data.line[j]:   MACGRUBER!
# data.line[j]:    I have ten seconds to read them or this whole place blows up.
# data.line[j]:   I’ve never really been a costume guy. Even when I was a kid, it just felt like something I was too old for. And then this morning, when Pam hands me this little number  …no.
# data.line[j]:    I am Popeye!
# data.line[j]:   Oh, here we go!
# data.line[j]:   Lame. Why don’t witches wear panties?
# data.line[j]:   MACGRUBER!
# data.line[j]:    I have ten seconds to read them or this whole place blows up.
# data.line[j]:    OH! Who likes to water ski on Lake Erie? No wai-where does Dracula like to water ski?
# data.line[j]:   Because they need to grip the broom!
# data.line[j]:   Oh, here we go!
# data.line[j]:   Lame. Why don’t witches wear panties?
# data.line[j]:   So, wait, drivers are going to be able to sell paper on the road?
# data.line[j]:    When our warehouse workers make deliveries, they’re going to be encouraged to offer clients extra products. And then they will split those commissions with sales.
# data.line[j]:   Lake Erie.
# data.line[j]:    OH! Who likes to water ski on Lake Erie? No wai-where does Dracula like to water ski?
# data.line[j]:   Blackula!
# data.line[j]:   Okay, guys, fun is fun, but-
# data.line[j]:   Gabe-wad.
# data.line[j]:   Not here.
# data.line[j]:   Oh, so… I almost forgot. You’ll find this hilarious. Apparently corporate is going to have drivers sell paper on their routes now. That’s like, exactly sort of the idea that you had.
# data.line[j]:   Dracula.
# data.line[j]:   Blackula!
# data.line[j]:   Okay, guys, fun is fun, but-
# data.line[j]:   Yeah. I’m sorry. I blew this. You should have gotten credit for that, man.
# data.line[j]:   Yes. I do remember saying something like that to you.
# data.line[j]:   Oh, so… I almost forgot. You’ll find this hilarious. Apparently corporate is going to have drivers sell paper on their routes now. That’s like, exactly sort of the idea that you had.
# data.line[j]:   Dracula.
# data.line[j]:   Really? We’re good?
# data.line[j]:   I’m just glad we’re gonna try it out.
# data.line[j]:   Yeah. I’m sorry. I blew this. You should have gotten credit for that, man.
# data.line[j]:   Yes. I do remember saying something like that to you.
# data.line[j]:   Okay.  Okay.
# data.line[j]:   Yeah. We’re cool.
# data.line[j]:   Really? We’re good?
# data.line[j]:   I’m just glad we’re gonna try it out.
# data.line[j]:   Oh. It’s a ream of paper. Thought you might hit me.
# data.line[j]:   What’s under your shirt?
# data.line[j]:   Okay.  Okay.
# data.line[j]:   Yeah. We’re cool.
# data.line[j]:   Darryl Philbin is the greatest guy in the world. And you know what I’d like? I would like to have all the racists brought together and take Darryl Philbin out to lunch. Just to see what they’re missing.
# data.line[j]:   Oh. It’s a ream of paper. Thought you might hit me.
# data.line[j]:   What’s under your shirt?
# data.line[j]:   Okay.  Okay.
# data.line[j]:   Erin! Would you please do me a solid and get Darryl Philbin on the speakerphone?
# data.line[j]:   Madge from the warehouse just made her first sale. Madge. We should have been doing this a long time ago.
# data.line[j]:    Creed’s going?!
# data.line[j]:   Yeah, and everyone else is gonna be there. Stanley, Phyllis, Angela, Darryl… Creed’s a maybe.
# data.line[j]:   Hi, Darryl, come out here, please.
# data.line[j]:    Hello?
# data.line[j]:   Erin! Would you please do me a solid and get Darryl Philbin on the speakerphone?
# data.line[j]:   Madge from the warehouse just made her first sale. Madge. We should have been doing this a long time ago.
# data.line[j]:   You need to stop being so shy, come out here, and embrace who you really are, superstar!
# data.line[j]:   I’m good.
# data.line[j]:   Hi, Darryl, come out here, please.
# data.line[j]:    Hello?
# data.line[j]:   Yeah, I bet it is! If you’re gonna do your job well here, you gotta get used to being embarrassed.
# data.line[j]:   This is embarrassing, Michael.
# data.line[j]:   You need to stop being so shy, come out here, and embrace who you really are, superstar!
# data.line[j]:   I’m good.
# data.line[j]:   This whole delivery slash sales idea? You know whose idea that was? That was Darryl Philbin’s. He thought of that way before the corporate fat suits.
# data.line[j]:    Um, hit the speakerphone button. The speakerphone button? The same button as you hit before… or sit on it.
# data.line[j]:   Let me put my shoes on.
# data.line[j]:   Yeah, I bet it is! If you’re gonna do your job well here, you gotta get used to being embarrassed.
# data.line[j]:   I got in the way. I said no. And it just stopped. But then corporate comes up with this idea, but you know what? They need to know that it was yours. And I don’t care if I take a bullet. We’re gonna call them, we’re gonna put them on speakerphone right now…
# data.line[j]:   So, what happened?
# data.line[j]:   This whole delivery slash sales idea? You know whose idea that was? That was Darryl Philbin’s. He thought of that way before the corporate fat suits.
# data.line[j]:    Um, hit the speakerphone button. The speakerphone button? The same button as you hit before… or sit on it.
# data.line[j]:   And we are going to straighten this out.
# data.line[j]:   Oh!
# data.line[j]:   I got in the way. I said no. And it just stopped. But then corporate comes up with this idea, but you know what? They need to know that it was yours. And I don’t care if I take a bullet. We’re gonna call them, we’re gonna put them on speakerphone right now…
# data.line[j]:   So, what happened?
# data.line[j]:   Mmhm!
# data.line[j]:   Screw corporate! They probably stole the idea anyway.
# data.line[j]:   And we are going to straighten this out.
# data.line[j]:   Oh!
# data.line[j]:   I’m a little peeved at Darryl right now.
# data.line[j]:   Uh uh. Corporate stole nothing, okay? Darryl told me, and then I told them, giving Darryl full credit, so… no need to
# data.line[j]:   Mmhm!
# data.line[j]:   Screw corporate! They probably stole the idea anyway.
# data.line[j]:   No, he didn’t go behind my back. He went over my head.
# data.line[j]:   He went to Gabe behind your back.
# data.line[j]:   I’m a little peeved at Darryl right now.
# data.line[j]:   Uh uh. Corporate stole nothing, okay? Darryl told me, and then I told them, giving Darryl full credit, so… no need to
# data.line[j]:   What is taking someone from behind?
# data.line[j]:   He went over your head to go behind your back.
# data.line[j]:   No, he didn’t go behind my back. He went over my head.
# data.line[j]:   He went to Gabe behind your back.
# data.line[j]:   It was a good idea, though.
# data.line[j]:   No. Shh. Michael, listen. This cannot stand. We can’t have workers going straight to corporate. Makes your job superfluous.
# data.line[j]:   What is taking someone from behind?
# data.line[j]:   He went over your head to go behind your back.
# data.line[j]:    What the hell are they talking about?
# data.line[j]:   Garbage magnet.  I can’t believe this doesn’t make you mad!
# data.line[j]:   This is an amazing prize. I mean, I don’t even want to give Pam a compliment, because she’s so blegh, but she did a good job. I really want that coupon book.
# data.line[j]:   Yeah, shut it, Oscar. Pam?
# data.line[j]:   Do you think that Kevin is going over my head? I don’t- Oh my GOD. Okay. All right. All right. You know what? That’s inappropriate, Kevin. I am your boss, and if you have something to say, it goes through me, and then I take it to Gabe. Chain of command. Do you understand?
# data.line[j]:   Hmm, Kevin and Gabe. Probably about the extremes of the human physique.
# data.line[j]:    What the hell are they talking about?
# data.line[j]:   Garbage magnet.  I can’t believe this doesn’t make you mad!
# data.line[j]:   Oh, you’re sorry?
# data.line[j]:   I am so sorry.
# data.line[j]:   Do you think that Kevin is going over my head? I don’t- Oh my GOD. Okay. All right. All right. You know what? That’s inappropriate, Kevin. I am your boss, and if you have something to say, it goes through me, and then I take it to Gabe. Chain of command. Do you understand?
# data.line[j]:   Hmm, Kevin and Gabe. Probably about the extremes of the human physique.
# data.line[j]:   What did you just thought?
# data.line[j]:   I just thought-
# data.line[j]:   Oh, you’re sorry?
# data.line[j]:   I am so sorry.
# data.line[j]:   All right.
# data.line[j]:   Well, Gabe asked me if there were any really cool Lady Gaga moves that he could do for the catwalk. And so then I tol-
# data.line[j]:   What did you just thought?
# data.line[j]:   I just thought-
# data.line[j]:   Okay.
# data.line[j]:   I told him that there was this one cool move where she powers down like a robot.
# data.line[j]:   All right.
# data.line[j]:   Well, Gabe asked me if there were any really cool Lady Gaga moves that he could do for the catwalk. And so then I tol-
# data.line[j]:   Well, don’t let it happen again.
# data.line[j]:   Okay? But I- I am so sorry that I didn’t tell you first.
# data.line[j]:   Okay.
# data.line[j]:   I told him that there was this one cool move where she powers down like a robot.
# data.line[j]:   I-
# data.line[j]:    You think that I would let this happen again?! NO WAY JOSE.
# data.line[j]:   Well, don’t let it happen again.
# data.line[j]:   Okay? But I- I am so sorry that I didn’t tell you first.
# data.line[j]:   Okay, this whole going over my head-gate? Is making people act weird. The chain of command is crumbling. Do you know what just happened? I just made Kevin cry. And Gabe looks like Lady Gaga. That’s not Halloween. Halloween should be a day in which we honor monsters and not be mad at each other.
# data.line[j]:   Hmm-mm.
# data.line[j]:    Well, great, I just wanted to make sure that things weren’t weird.
# data.line[j]:   Yeah?  It was though, that’s what happened.
# data.line[j]:   You went over my head. And then you lied to my face. So my head and my face have taken a beating.
# data.line[j]:   I’m not mad. Are you mad?
# data.line[j]:   Okay, this whole going over my head-gate? Is making people act weird. The chain of command is crumbling. Do you know what just happened? I just made Kevin cry. And Gabe looks like Lady Gaga. That’s not Halloween. Halloween should be a day in which we honor monsters and not be mad at each other.
# data.line[j]:   Hmm-mm.
# data.line[j]:   Okay, that might help. If you said “I’m sorry” in front of everybody.
# data.line[j]:   Well, I’m sorry if it seems that way to you.
# data.line[j]:   You went over my head. And then you lied to my face. So my head and my face have taken a beating.
# data.line[j]:   I’m not mad. Are you mad?
# data.line[j]:   In front of me.
# data.line[j]:   Mike.
# data.line[j]:   Okay, that might help. If you said “I’m sorry” in front of everybody.
# data.line[j]:   Well, I’m sorry if it seems that way to you.
# data.line[j]:   So that’s it.
# data.line[j]:   You made a bad call. And I fixed it. So I’m not apologizing.
# data.line[j]:   In front of me.
# data.line[j]:   Mike.
# data.line[j]:   Is it?
# data.line[j]:   That’s it.
# data.line[j]:   So that’s it.
# data.line[j]:   You made a bad call. And I fixed it. So I’m not apologizing.
# data.line[j]:   Yeah, I gotta get in on this.  Hey, it’s cool, man, I work in the warehouse! I’m cool! I’m hip and I’m jive! And I don’t care about nobody! Do you know who I am? Happy Halloween, jerk!
# data.line[j]:   Pam. Can you vote for other people?
# data.line[j]:   Okay, everybody! After you walk the runway everyone has to vote for who gets the coupon book. And you can’t vote for yourself.
# data.line[j]:   Yeah, I uh, heard you say it to Phyllis. That’s a good line.
# data.line[j]:   Still don’t know who I am? I’ll give you a hint. I go over other people’s heads.
# data.line[j]:   Yeah, I gotta get in on this.  Hey, it’s cool, man, I work in the warehouse! I’m cool! I’m hip and I’m jive! And I don’t care about nobody! Do you know who I am? Happy Halloween, jerk!
# data.line[j]:   Pam. Can you vote for other people?
# data.line[j]:   Okay, everybody! After you walk the runway everyone has to vote for who gets the coupon book. And you can’t vote for yourself.
# data.line[j]:   What’s a bad idea?
# data.line[j]:   Michael, this is a bad idea.
# data.line[j]:   Still don’t know who I am? I’ll give you a hint. I go over other people’s heads.
# data.line[j]:   Yeah, I gotta get in on this.  Hey, it’s cool, man, I work in the warehouse! I’m cool! I’m hip and I’m jive! And I don’t care about nobody! Do you know who I am? Happy Halloween, jerk!
# data.line[j]:   NEVER!  Okay, you know what? Fine.  I’m not Darryl. And thank God I’m not Darryl.
# data.line[j]:   Dressing up as somebody-I mean, when has that ever worked for you?
# data.line[j]:   What’s a bad idea?
# data.line[j]:   Michael, this is a bad idea.
# data.line[j]:   Hey, can I play? Why don’t you ask if Darryl is a bad friend who backstabs people in the back?
# data.line[j]:   What should we ask?
# data.line[j]:   I don’t like your tone! Look, they were sold out of all the other costumes, okay? I think we all live in the real world, here. Let’s not pretend to be unaware of what sells in this office.
# data.line[j]:   Angela as the nurse!
# data.line[j]:   Aaah! Darryl moved it. You moved it.
# data.line[j]:   He says no.
# data.line[j]:   We have one question to ask the spirit world and you want us to ask that?
# data.line[j]:   Hey, can I play? Why don’t you ask if Darryl is a bad friend who backstabs people in the back?
# data.line[j]:   Dwight, you saw Darryl move it, right?
# data.line[j]:   No.
# data.line[j]:   Aaah! Darryl moved it. You moved it.
# data.line[j]:   He says no.
# data.line[j]:   If you had one word you would use to describe Darryl what would that word be?
# data.line[j]:   I know how to sit on a fence. Hell, I can even sleep on a fence. The trick is to do it face down with the post in your mouth.
# data.line[j]:   Let’s just say I saw exactly what the two of you wanted me to see.
# data.line[j]:   Dwight, you saw Darryl move it, right?
# data.line[j]:   Thank you.
# data.line[j]:   In the future, you need to get Michael’s approval on anything before coming to me.
# data.line[j]:   Thank you! Thank you. I got it. Now I know. You thought I was a little dorky. You know?  Okay. Well, excuuuuse me.
# data.line[j]:   Hey, man.
# data.line[j]:   If they’re good ideas, I’m not gonna say no!
# ...
# data.line[j]:   My last pay check?
# data.line[j]:    Oh Michael! Where do you want your last pay check sent?
# data.line[j]:    Walk away bitch.
# data.line[j]:   Let’s rip it up homes.
# data.line[j]:   No.
# data.line[j]:   You have an address yet in Colorado?
# data.line[j]:   My last pay check?
# data.line[j]:    Oh Michael! Where do you want your last pay check sent?
# data.line[j]:   I’m not sure, um, Mountainton?
# data.line[j]:   What town do Holly’s parents live in?
# data.line[j]:   No.
# data.line[j]:   You have an address yet in Colorado?
# data.line[j]:   Nah, I’m almost done.
# data.line[j]:    Hey! It’s almost your last day, come sit with us.
# data.line[j]:   I’m going to!
# data.line[j]:    You should do more stuff like that.
# data.line[j]:   Yeah.
# data.line[j]:   You sure?
# data.line[j]:   Nah, I’m almost done.
# data.line[j]:    Hey! It’s almost your last day, come sit with us.
# data.line[j]:
# data.line[j]:   I don’t think any of them are supposed to shred magazines.
# data.line[j]:   No, it’s just… that old shredder sucks.  Just get one that’ll shred magazines.
# data.line[j]:   Did you break the shredder Kevin?
# data.line[j]:   Hi. What is the name of our town?
# data.line[j]:    Hello there!
# data.line[j]:
# data.line[j]:   I don’t think any of them are supposed to shred magazines.
# data.line[j]:   No, no. I just needed to hear your voice.
# data.line[j]:   Boulder. Is something wrong? Are you okay?
# data.line[j]:   Hi. What is the name of our town?
# data.line[j]:    Hello there!
# data.line[j]:    Yes my hero!
# data.line[j]:    Oh you mean this?
# data.line[j]:   No, no. I just needed to hear your voice.
# data.line[j]:   Boulder. Is something wrong? Are you okay?
# data.line[j]:    Ohh, I miss you.
# data.line[j]:    Okay, my mom’s looking at me and she has no sense of humor. It’s a joke mom!
# data.line[j]:    Yes my hero!
# data.line[j]:    Oh you mean this?
# data.line[j]:   Okay. I’ll see you tonight. I love you.
# data.line[j]:   Well I’ll see you tonight. I’ll pick you up outside baggage claim.
# data.line[j]:    Ohh, I miss you.
# data.line[j]:    Okay, my mom’s looking at me and she has no sense of humor. It’s a joke mom!
# data.line[j]:    And I have said goodbye to half of them.
# data.line[j]:   I love you too.
# data.line[j]:   Okay. I’ll see you tonight. I love you.
# data.line[j]:   Well I’ll see you tonight. I’ll pick you up outside baggage claim.
# data.line[j]:    Okay.
# data.line[j]:   Well you know Michael, I have a brother in Boulder. Rory Flenderson. You should look him up.
# data.line[j]:    And I have said goodbye to half of them.
# data.line[j]:   I love you too.
# data.line[j]:    Kelly! Kelly? Kelly.
# data.line[j]:    Okay.
# data.line[j]:    Okay.
# data.line[j]:   Well you know Michael, I have a brother in Boulder. Rory Flenderson. You should look him up.
# data.line[j]:   If I just went away right now, would that be the best gift that I could give you?
# data.line[j]:    What?!
# data.line[j]:    Kelly! Kelly? Kelly.
# data.line[j]:    Okay.
# data.line[j]:    She was once my girl, and she is your girl now.
# data.line[j]:   Yes! Please! Please go away! And stop using that weird slow voice.
# data.line[j]:   If I just went away right now, would that be the best gift that I could give you?
# data.line[j]:    What?!
# data.line[j]:   Yeah.
# data.line[j]:   Wow.
# data.line[j]:    She was once my girl, and she is your girl now.
# data.line[j]:   Yes! Please! Please go away! And stop using that weird slow voice.
# data.line[j]:   You’re not prone to seizures?
# data.line[j]:   This is… totally unnecessary.
# data.line[j]:   Yeah.
# data.line[j]:   Wow.
# data.line[j]:    Um, Pam.
# data.line[j]:   No! I’m not cleaning up a bunch of uneaten cupcake bottoms! You know, we don’t really care about your opinion. You’re just a tie-breaker.
# data.line[j]:   Yeah, cupcakes. That’s what I said.
# data.line[j]:   I think we should do cupcakes. I am one of the few people who looks hot eating a cupcake.
# data.line[j]:
# data.line[j]:   Oh, hey Michael! I’m just going to go to Carbondale to price some shredders. I’ll see you later.
# data.line[j]:    Um, Pam.
# data.line[j]:   No! I’m not cleaning up a bunch of uneaten cupcake bottoms! You know, we don’t really care about your opinion. You’re just a tie-breaker.
# data.line[j]:    Darryl!
# data.line[j]:   Well, no. He hates jams.
# data.line[j]:   Does he like jams? My shelves are over flowing with preserves.
# data.line[j]:   Do- Well you should give him a little time to settle in. But-
# data.line[j]:   I would like to give you, the only copy, of Somehow I Manage.  Unfinished. If there’s anyone here who can finish it, it’s you.
# data.line[j]:   Hey.
# data.line[j]:    Darryl!
# data.line[j]:   Well, no. He hates jams.
# data.line[j]:   Mmmhmmm. It’s true. Darryl, I have one last wish. I would like to use the bailer.
# data.line[j]:   That’s sweet Mike. Let’s see here. There’s a chapter, called Gum. With one sentence. Everybody likes the guy who offers him a stick of gum.
# data.line[j]:   I would like to give you, the only copy, of Somehow I Manage.  Unfinished. If there’s anyone here who can finish it, it’s you.
# data.line[j]:   Hey.
# data.line[j]:   No problem. Worth a try.
# data.line[j]:   No. Can’t let you do that Mike.
# data.line[j]:   Mmmhmmm. It’s true. Darryl, I have one last wish. I would like to use the bailer.
# data.line[j]:   That’s sweet Mike. Let’s see here. There’s a chapter, called Gum. With one sentence. Everybody likes the guy who offers him a stick of gum.
# data.line[j]:    Darryl said I could use the bailer because I’m leaving.
# data.line[j]:   No problem. Worth a try.
# data.line[j]:   No. Can’t let you do that Mike.
# data.line[j]:   Mmmhmmm. It’s true. Darryl, I have one last wish. I would like to use the bailer.
# data.line[j]:
# data.line[j]:   No.
# data.line[j]:    Darryl said I could use the bailer because I’m leaving.
# data.line[j]:   No problem. Worth a try.
# data.line[j]:
# data.line[j]:   Not while I’m driving.
# data.line[j]:    Alright.
# data.line[j]:   ‘Cause if you do now’s the time.
# data.line[j]:   Kevin?
# data.line[j]:   I know that Gabe is young, and hot and everything. And he’s begging me to reconsider, but I… I just think I’m in love with someone else.
# data.line[j]:   Wooo! Yeah!  Okay, again.
# data.line[j]:   Mmhmmm.
# data.line[j]:   Ahhhh…
# data.line[j]:   Andy.
# data.line[j]:   Kevin?
# data.line[j]:   I know that Gabe is young, and hot and everything. And he’s begging me to reconsider, but I… I just think I’m in love with someone else.
# data.line[j]:   Maybe neither.
# data.line[j]:   I wish I knew who my birth mother was, so she could just tell me who to choose.
# data.line[j]:   Ahhhh…
# data.line[j]:   Andy.
# data.line[j]:   Erin, listen to me. You shouldn’t rush into this. At all. And you know why? Because you are beautiful. And you are fun. And you are smart.  And you know what? You don’t need a mom. Because you have my number, and you can call me anytime.
# data.line[j]:   I’m not attracted to Kevin.
# data.line[j]:   Maybe neither.
# data.line[j]:   I wish I knew who my birth mother was, so she could just tell me who to choose.
# data.line[j]:   N-
# data.line[j]:    Extension 147.
# data.line[j]:   Erin, listen to me. You shouldn’t rush into this. At all. And you know why? Because you are beautiful. And you are fun. And you are smart.  And you know what? You don’t need a mom. Because you have my number, and you can call me anytime.
# data.line[j]:   I’m not attracted to Kevin.
# data.line[j]:   Okay.
# data.line[j]:   I know.
# data.line[j]:   N-
# data.line[j]:    Extension 147.
# data.line[j]:   Phyllis. Phyllis, are my mittens done?
# data.line[j]:    You want the 27-26 or the 27-30?
# data.line[j]:   Okay.
# data.line[j]:   I know.
# data.line[j]:   Listen to me. It’s two p.m. From now until four, your priority is knitting. Knit like the wind.
# data.line[j]:   No.  I’m on a sale!
# data.line[j]:   Phyllis. Phyllis, are my mittens done?
# data.line[j]:    You want the 27-26 or the 27-30?
# data.line[j]:   Dwight, I will be leaving tomorrow.
# data.line[j]:   Okay…
# data.line[j]:   Listen to me. It’s two p.m. From now until four, your priority is knitting. Knit like the wind.
# data.line[j]:   No.  I’m on a sale!
# data.line[j]:   So I wanted to give you that.
# data.line[j]:   Yes.
# data.line[j]:   Dwight, I will be leaving tomorrow.
# data.line[j]:   Okay…
# data.line[j]:
# data.line[j]:
# data.line[j]:   This is gonna be good.  The dictionary defines superlative as:
# data.line[j]:   So I wanted to give you that.
# data.line[j]:   You should see the other guy.
# data.line[j]:    Ahh, what happened to you?
# data.line[j]:    But I can say this:
# data.line[j]:
# data.line[j]:    Jim where is Pam?
# data.line[j]:
# data.line[j]:   You should see the other guy.
# data.line[j]:    Ahh, what happened to you?
# data.line[j]:   But it is already three o’clock!
# data.line[j]:   Uhh, she’s still pricing the whatevers. The shredders.
# data.line[j]:    Jim where is Pam?
# data.line[j]:
# data.line[j]:    Whether you’re scared of dying, or dying Alone, or dying drunk in a ditch. Don’t be. It’s going to be okay.
# data.line[j]:
# data.line[j]:   But it is already three o’clock!
# data.line[j]:   Uhh, she’s still pricing the whatevers. The shredders.
# data.line[j]:   Yeah I was tripling up. There’s not enough time in the day to have a special moment with everybody.
# data.line[j]:    Whether you’re scared of dying, or dying Alone, or dying drunk in a ditch. Don’t be. It’s going to be okay.
# data.line[j]:
# data.line[j]:   But it is already three o’clock!
# data.line[j]:    And you, why are you still here.
# data.line[j]:   Yeah I was tripling up. There’s not enough time in the day to have a special moment with everybody.
# data.line[j]:    Whether you’re scared of dying, or dying Alone, or dying drunk in a ditch. Don’t be. It’s going to be okay.
# data.line[j]:
# data.line[j]:    No, you are not going to quit today. For goodness sake, this is not going to be your last day in the office. Everybody gets dumped Gabe. Can I give you a piece of advice?
# data.line[j]:    I’m either going to quit today, or stay to make sure that Andy’s career is destroyed.
# data.line[j]:    And you, why are you still here.
# data.line[j]:   Yeah I was tripling up. There’s not enough time in the day to have a special moment with everybody.
# data.line[j]:
# data.line[j]:   We did it!
# data.line[j]:    Good job boss!
# data.line[j]:    You’ll never guess, we did it!
# data.line[j]:   What is this meeting about?
# data.line[j]:   Yes, what is this about?
# data.line[j]:
# data.line[j]:   We did it!
# data.line[j]:   Okay, here we are in the conference room. Once again. And I just wanted to call you all here, together, because I have something important. Well there’s two things actually. Okay first, I would like a whereabouts on Pam.  And secondly, Phyllis how are those mittens coming? Because I would actually like to bring them home and pack them. I’m leaving for the day at four.
# data.line[j]:   Mmhmmm.
# data.line[j]:   What is this meeting about?
# data.line[j]:   Yes, what is this about?
# data.line[j]:    Well power through the arthritis Phyllis you can do it!
# data.line[j]:   They’re almost done but my knuckles are swelling a little and-
# data.line[j]:   Okay, here we are in the conference room. Once again. And I just wanted to call you all here, together, because I have something important. Well there’s two things actually. Okay first, I would like a whereabouts on Pam.  And secondly, Phyllis how are those mittens coming? Because I would actually like to bring them home and pack them. I’m leaving for the day at four.
# data.line[j]:   Mmhmmm.
# data.line[j]:   Umm, hmm?
# data.line[j]:   Is that it?
# data.line[j]:    Well power through the arthritis Phyllis you can do it!
# data.line[j]:   They’re almost done but my knuckles are swelling a little and-
# data.line[j]:    I ruv you all! I ruv you very much!
# data.line[j]:   Is that it?
# data.line[j]:   Umm, hmm?
# data.line[j]:   Is that it?
# data.line[j]:   Sure.  Be right out!
# data.line[j]:   Hey, can I talk to you for a second?
# data.line[j]:    I ruv you all! I ruv you very much!
# data.line[j]:   Is that it?
# data.line[j]:    Ohh…
# data.line[j]:    So I’ve been meaning to tell ya, I wanna take you out for lunch. For your last day.
# data.line[j]:   Sure.  Be right out!
# data.line[j]:   Hey, can I talk to you for a second?
# data.line[j]:    Okay…
# data.line[j]:   What do you think? Tomorrow? Lunch, you and me?
# data.line[j]:    Ohh…
# data.line[j]:    So I’ve been meaning to tell ya, I wanna take you out for lunch. For your last day.
# data.line[j]:   Maybe.
# data.line[j]:   You’re not leaving tomorrow. You’re leaving today right?
# data.line[j]:    Okay…
# data.line[j]:   What do you think? Tomorrow? Lunch, you and me?
# data.line[j]:   Why am I so sad? Am I doing the wrong thing?
# data.line[j]:   Wow, so that’s it huh? Just, four o’clock and you are gone for good.
# data.line[j]:   Maybe.
# data.line[j]:   You’re not leaving tomorrow. You’re leaving today right?
# data.line[j]:    You started with this company, as a fine young man…
# data.line[j]:   Absolutely not. It’s just that sometimes… goodbyes are a bitch.
# data.line[j]:   Why am I so sad? Am I doing the wrong thing?
# data.line[j]:   Wow, so that’s it huh? Just, four o’clock and you are gone for good.
# data.line[j]:   Oh, okay.
# data.line[j]:   You know what I think we should do? I think we should just save the goodbyes for tomorrow. At lunch.
# data.line[j]:    You started with this company, as a fine young man…
# data.line[j]:   Absolutely not. It’s just that sometimes… goodbyes are a bitch.
# data.line[j]:    Oh shoot! That’s my cab.
# data.line[j]:   And then tomorrow, I can tell you… what a great boss, you turned out to be. The best boss I ever had.
# data.line[j]:   Oh, okay.
# data.line[j]:   You know what I think we should do? I think we should just save the goodbyes for tomorrow. At lunch.
# data.line[j]:   Alright.
# data.line[j]:   Alright.
# data.line[j]:    Oh shoot! That’s my cab.
# data.line[j]:   And then tomorrow, I can tell you… what a great boss, you turned out to be. The best boss I ever had.
# data.line[j]:   I know, it’s okay. Just, give her a hug. Alright?
# data.line[j]:   Listen Michael, I really… I did text Pam, but…
# data.line[j]:   Alright.
# data.line[j]:   Alright.
# data.line[j]:   I am looking forward to lunch. And hearing about what a great boss I am.
# data.line[j]:    I will see you, tomorrow at lunch.
# data.line[j]:   I know, it’s okay. Just, give her a hug. Alright?
# data.line[j]:   Listen Michael, I really… I did text Pam, but…
# data.line[j]:   Okay…  Phyllis.
# data.line[j]:    You got it.
# data.line[j]:   I am looking forward to lunch. And hearing about what a great boss I am.
# data.line[j]:    I will see you, tomorrow at lunch.
# data.line[j]:   No no no, let me see.
# data.line[j]:   Oh no, they’re still not done.
# data.line[j]:   Okay…  Phyllis.
# data.line[j]:    You got it.
# data.line[j]:   Later guys.
# data.line[j]:    See ya tomorrow boss!
# data.line[j]:   No no no, let me see.
# data.line[j]:   Oh no, they’re still not done.
# data.line[j]:   Got almost everybody. So… Holly’s my family now.  I actually don’t understand deathbeds. I mean, who would buy that?
# data.line[j]:   Later guys.
# data.line[j]:    See ya tomorrow boss!
# data.line[j]:   No no no, let me see.
# data.line[j]:
# data.line[j]:   Got almost everybody. So… Holly’s my family now.  I actually don’t understand deathbeds. I mean, who would buy that?
# data.line[j]:   Later guys.
# data.line[j]:    See ya tomorrow boss!
# data.line[j]:   That’s what she said.
# data.line[j]:    Michael. I can’t believe you came.
# data.line[j]:   I just…really wish there was something I could do.
# data.line[j]:   Jim.
# data.line[j]:    I feel like all my kids grew up and then they married each other. It’s every parent’s dream.
# data.line[j]:   If Ryan wants his baby back, please tell him where to fine me. We’ll be somewhere in Europe.  Won’t we?
# data.line[j]:   Yes. It is. Oh yes it is.
# data.line[j]:   Hey, this is better.

# %%
df.sample(6)
# Out:
#                                                response  \
# 7690                                      Who’s there?
# 4347                         Oh.  Come on.  Be serious.
# 8925                                              Yeah.
# 5742   Well have a seat, or come on in, or, I don’t ...
# 8978                          You know what it means.
# 2203   Once, as a joke, Packer banged every chick in...
#
#                                                 context  \
# 7690                                         Ding Dong.
# 4347                                      There you go.
# 8925                                               Fun!
# 5742   Oh well Pam, thank you, this will be great to...
# 8978                    What’s that supposed to mean?
# 2203                                  Oh, okay.  Gah.
#
#                                               context/0  \
# 7690   Mine was retribution. What are you doing? No ...
# 4347   Because, that is the way these things are don...
# 8925                                       Erin, look.
# 5742                                  We got you this.
# 8978    You know what?  I’m gonna start dating her e...
# 2203                You shouldn’t have hit me, Michael.
#
#                                               context/1
# 7690   C’mon. What are you doing? Mine was a part of...
# 4347                        Why can’t I just… tell you?
# 8925   Michael, you’re all set at Botticelli’s. I ch...
# 5742                                    Except driving.
# 8978    Michael, let me make this very easy for you,...
# 2203                                     Charley horse!

# %%
trn_df, val_df = train_test_split(df, test_size=0.1)
trn_df.head()
# Out:
#                                                response  \
# 5738         Yes I would. So, what have you been doing?
# 6552   I will be honest with you.  That car ride did...
# 7948   You know what they say, keep your friends clo...
# 9178                                                No.
# 5187                                   Yes.  Thank you.
#
#                                                 context  \
# 5738   Chilly huh? So glad we finally got to do this...
# 6552            It’s not a family.  It’s a workplace.
# 7948                                        I’m good.
# 9178                              Can I have an office?
# 5187                                       I’m driving?
#
#                                               context/0  \
# 5738                       Come on in. Good to see you.
# 6552   Well, you have to tolerate a lot when you are...
# 7948                          Yeah, I’m good. You good?
# 9178                                       Forget that.
# 5187    Alright.  I’m ready to go and I’m callin’ sh...
#
#                                               context/1
# 5738                                       How are you?
# 6552   I’m saying that her behavior is unethical and...
# 7948                                      Are you good?
# 9178               Do it.  Promote me.  Tri-managers.
# 5187    Yes, Mr. Galliado.  How would you like to pa...

# %%
# create dataset suitable for our model
def construct_conv(row, tokenizer, eos = True):
    flatten = lambda l: [item for sublist in l for item in sublist]
    conv = list(reversed([tokenizer.encode(x) + [tokenizer.eos_token_id] for x in row]))
    conv = flatten(conv)
    return conv

class ConversationDataset(Dataset):
    def __init__(self, tokenizer: PreTrainedTokenizer, args, df, block_size=512):

        block_size = block_size - (tokenizer.model_max_length - tokenizer.max_len_single_sentence)

        directory = args.cache_dir
        cached_features_file = os.path.join(
            directory, args.model_type + "_cached_lm_" + str(block_size)
        )

        if os.path.exists(cached_features_file) and not args.overwrite_cache:
            logger.info("Loading features from cached file %s", cached_features_file)
            with open(cached_features_file, "rb") as handle:
                self.examples = pickle.load(handle)
        else:
            logger.info("Creating features from dataset file at %s", directory)

            self.examples = []
            for _, row in df.iterrows():
                conv = construct_conv(row, tokenizer)
                self.examples.append(conv)

            logger.info("Saving features into cached file %s", cached_features_file)
            with open(cached_features_file, "wb") as handle:
                pickle.dump(self.examples, handle, protocol=pickle.HIGHEST_PROTOCOL)

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, item):
        return torch.tensor(self.examples[item], dtype=torch.long)

# %%
# Cacheing and storing of data/checkpoints

def load_and_cache_examples(args, tokenizer, df_trn, df_val, evaluate=False):
    return ConversationDataset(tokenizer, args, df_val if evaluate else df_trn)


def set_seed(args):
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if args.n_gpu > 0:
        torch.cuda.manual_seed_all(args.seed)


def _sorted_checkpoints(args, checkpoint_prefix="checkpoint", use_mtime=False) -> List[str]:
    ordering_and_checkpoint_path = []

    glob_checkpoints = glob.glob(os.path.join(args.output_dir, "{}-*".format(checkpoint_prefix)))

    for path in glob_checkpoints:
        if use_mtime:
            ordering_and_checkpoint_path.append((os.path.getmtime(path), path))
        else:
            regex_match = re.match(".*{}-([0-9]+)".format(checkpoint_prefix), path)
            if regex_match and regex_match.groups():
                ordering_and_checkpoint_path.append((int(regex_match.groups()[0]), path))

    checkpoints_sorted = sorted(ordering_and_checkpoint_path)
    checkpoints_sorted = [checkpoint[1] for checkpoint in checkpoints_sorted]
    return checkpoints_sorted


def _rotate_checkpoints(args, checkpoint_prefix="checkpoint", use_mtime=False) -> None:
    if not args.save_total_limit:
        return
    if args.save_total_limit <= 0:
        return

    # Check if we should delete older checkpoint(s)
    checkpoints_sorted = _sorted_checkpoints(args, checkpoint_prefix, use_mtime)
    if len(checkpoints_sorted) <= args.save_total_limit:
        return

    number_of_checkpoints_to_delete = max(0, len(checkpoints_sorted) - args.save_total_limit)
    checkpoints_to_be_deleted = checkpoints_sorted[:number_of_checkpoints_to_delete]
    for checkpoint in checkpoints_to_be_deleted:
        logger.info("Deleting older checkpoint [{}] due to args.save_total_limit".format(checkpoint))
        shutil.rmtree(checkpoint)

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.38.2
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by:

# %%
from transformers import AutoModelWithLMHead, AutoModelForCausalLM, AutoTokenizer
import torch


tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-small")
model = AutoModelWithLMHead.from_pretrained("output-small")

model.save_pretrained("output-small-3")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1595: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(

# %% [markdown]
# ## Build Model

# %%
from transformers import AutoModelWithLMHead, AutoModelForCausalLM, AutoTokenizer
import torch


tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-small")
model = AutoModelWithLMHead.from_pretrained("microsoft/DialoGPT-small")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1595: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# config.json:   0%|          | 0.00/641 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/351M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
"""
Fine-tuning the library models for language modeling on a text file (GPT, GPT-2, BERT, RoBERTa).
GPT and GPT-2 are fine-tuned using a causal language modeling (CLM) loss while BERT and RoBERTa are fine-tuned
using a masked language modeling (MLM) loss.
"""

# Configs
logger = logging.getLogger(__name__)

MODEL_CONFIG_CLASSES = list(MODEL_WITH_LM_HEAD_MAPPING.keys())
MODEL_TYPES = tuple(conf.model_type for conf in MODEL_CONFIG_CLASSES)

# %%
# Args to allow for easy convertion of python script to notebook
class Args():
    def __init__(self):
        self.output_dir = 'output-small_2'
        self.model_type = 'gpt2'
        self.model_name_or_path = 'microsoft/DialoGPT-small'
        self.config_name = 'microsoft/DialoGPT-small'
        self.tokenizer_name = 'microsoft/DialoGPT-small'
        self.cache_dir = 'cached'
        self.block_size = 512
        self.do_train = True
        self.do_eval = True
        self.evaluate_during_training = False
        self.per_gpu_train_batch_size = 4
        self.per_gpu_eval_batch_size = 4
        self.gradient_accumulation_steps = 1
        self.learning_rate = 5e-5
        self.weight_decay = 0.0
        self.adam_epsilon = 1e-8
        self.max_grad_norm = 1.0
        self.num_train_epochs = 10
        self.max_steps = -1
        self.warmup_steps = 0
        self.logging_steps = 1000
        self.save_steps = 3500
        self.save_total_limit = None
        self.eval_all_checkpoints = False
        self.no_cuda = False
        self.overwrite_output_dir = True
        self.overwrite_cache = True
        self.should_continue = False
        self.seed = 42
        self.local_rank = -1
        self.fp16 = False
        self.fp16_opt_level = 'O1'

args = Args()

# %% [markdown]
# ## Train and Evaluate

# %%
def train(args, train_dataset, model: PreTrainedModel, tokenizer: PreTrainedTokenizer) -> Tuple[int, float]:
    """ Train the model """
    if args.local_rank in [-1, 0]:
        tb_writer = SummaryWriter()

    args.train_batch_size = args.per_gpu_train_batch_size * max(1, args.n_gpu)

    def collate(examples: List[torch.Tensor]):
        if tokenizer._pad_token is None:
            return pad_sequence(examples, batch_first=True)
        return pad_sequence(examples, batch_first=True, padding_value=tokenizer.pad_token_id)

    train_sampler = RandomSampler(train_dataset) if args.local_rank == -1 else DistributedSampler(train_dataset)
    train_dataloader = DataLoader(
        train_dataset, sampler=train_sampler, batch_size=args.train_batch_size, collate_fn=collate, drop_last = True
    )

    if args.max_steps > 0:
        t_total = args.max_steps
        args.num_train_epochs = args.max_steps // (len(train_dataloader) // args.gradient_accumulation_steps) + 1
    else:
        t_total = len(train_dataloader) // args.gradient_accumulation_steps * args.num_train_epochs

    model = model.module if hasattr(model, "module") else model  # Take care of distributed/parallel training
    model.resize_token_embeddings(len(tokenizer))
    # add_special_tokens_(model, tokenizer)


    # Prepare optimizer and schedule (linear warmup and decay)
    no_decay = ["bias", "LayerNorm.weight"]
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            "weight_decay": args.weight_decay,
        },
        {"params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], "weight_decay": 0.0},
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=args.learning_rate, eps=args.adam_epsilon)
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=args.warmup_steps, num_training_steps=t_total
    )

    # Check if saved optimizer or scheduler states exist
    if (
        args.model_name_or_path
        and os.path.isfile(os.path.join(args.model_name_or_path, "optimizer.pt"))
        and os.path.isfile(os.path.join(args.model_name_or_path, "scheduler.pt"))
    ):
        # Load in optimizer and scheduler states
        optimizer.load_state_dict(torch.load(os.path.join(args.model_name_or_path, "optimizer.pt")))
        scheduler.load_state_dict(torch.load(os.path.join(args.model_name_or_path, "scheduler.pt")))

    if args.fp16:
        try:
            from apex import amp
        except ImportError:
            raise ImportError("Please install apex from https://www.github.com/nvidia/apex to use fp16 training.")
        model, optimizer = amp.initialize(model, optimizer, opt_level=args.fp16_opt_level)

    # multi-gpu training (should be after apex fp16 initialization)
    if args.n_gpu > 1:
        model = torch.nn.DataParallel(model)

    # Distributed training (should be after apex fp16 initialization)
    if args.local_rank != -1:
        model = torch.nn.parallel.DistributedDataParallel(
            model, device_ids=[args.local_rank], output_device=args.local_rank, find_unused_parameters=True
        )

    # Train!
    logger.info("***** Running training *****")
    logger.info("  Num examples = %d", len(train_dataset))
    logger.info("  Num Epochs = %d", args.num_train_epochs)
    logger.info("  Instantaneous batch size per GPU = %d", args.per_gpu_train_batch_size)
    logger.info(
        "  Total train batch size (w. parallel, distributed & accumulation) = %d",
        args.train_batch_size
        * args.gradient_accumulation_steps
        * (torch.distributed.get_world_size() if args.local_rank != -1 else 1),
    )
    logger.info("  Gradient Accumulation steps = %d", args.gradient_accumulation_steps)
    logger.info("  Total optimization steps = %d", t_total)

    global_step = 0
    epochs_trained = 0
    steps_trained_in_current_epoch = 0
    # Check if continuing training from a checkpoint
    if args.model_name_or_path and os.path.exists(args.model_name_or_path):
        try:
            # set global_step to gobal_step of last saved checkpoint from model path
            checkpoint_suffix = args.model_name_or_path.split("-")[-1].split("/")[0]
            global_step = int(checkpoint_suffix)
            epochs_trained = global_step // (len(train_dataloader) // args.gradient_accumulation_steps)
            steps_trained_in_current_epoch = global_step % (len(train_dataloader) // args.gradient_accumulation_steps)

            logger.info("  Continuing training from checkpoint, will skip to saved global_step")
            logger.info("  Continuing training from epoch %d", epochs_trained)
            logger.info("  Continuing training from global step %d", global_step)
            logger.info("  Will skip the first %d steps in the first epoch", steps_trained_in_current_epoch)
        except ValueError:
            logger.info("  Starting fine-tuning.")

    tr_loss, logging_loss = 0.0, 0.0

    model.zero_grad()
    train_iterator = trange(
        epochs_trained, int(args.num_train_epochs), desc="Epoch", disable=args.local_rank not in [-1, 0]
    )
    set_seed(args)  # Added here for reproducibility
    for _ in train_iterator:
        epoch_iterator = tqdm(train_dataloader, desc="Iteration", disable=args.local_rank not in [-1, 0])
        for step, batch in enumerate(epoch_iterator):

            # Skip past any already trained steps if resuming training
            if steps_trained_in_current_epoch > 0:
                steps_trained_in_current_epoch -= 1
                continue

            inputs, labels = (batch, batch)
            if inputs.shape[1] > 1024: continue
            inputs = inputs.to(args.device)
            labels = labels.to(args.device)
            model.train()
            outputs = model(inputs, labels=labels)
            loss = outputs[0]  # model outputs are always tuple in transformers (see doc)

            if args.n_gpu > 1:
                loss = loss.mean()  # mean() to average on multi-gpu parallel training
            if args.gradient_accumulation_steps > 1:
                loss = loss / args.gradient_accumulation_steps

            if args.fp16:
                with amp.scale_loss(loss, optimizer) as scaled_loss:
                    scaled_loss.backward()
            else:
                loss.backward()

            tr_loss += loss.item()
            if (step + 1) % args.gradient_accumulation_steps == 0:
                if args.fp16:
                    torch.nn.utils.clip_grad_norm_(amp.master_params(optimizer), args.max_grad_norm)
                else:
                    torch.nn.utils.clip_grad_norm_(model.parameters(), args.max_grad_norm)
                optimizer.step()
                scheduler.step()  # Update learning rate schedule
                model.zero_grad()
                global_step += 1

                if args.local_rank in [-1, 0] and args.logging_steps > 0 and global_step % args.logging_steps == 0:
                    # Log metrics
                    if (
                        args.local_rank == -1 and args.evaluate_during_training
                    ):  # Only evaluate when single GPU otherwise metrics may not average well
                        results = evaluate(args, model, tokenizer)
                        for key, value in results.items():
                            tb_writer.add_scalar("eval_{}".format(key), value, global_step)
                    tb_writer.add_scalar("lr", scheduler.get_lr()[0], global_step)
                    tb_writer.add_scalar("loss", (tr_loss - logging_loss) / args.logging_steps, global_step)
                    logging_loss = tr_loss

                if args.local_rank in [-1, 0] and args.save_steps > 0 and global_step % args.save_steps == 0:
                    checkpoint_prefix = "checkpoint"
                    # Save model checkpoint
                    output_dir = os.path.join(args.output_dir, "{}-{}".format(checkpoint_prefix, global_step))
                    os.makedirs(output_dir, exist_ok=True)
                    model_to_save = (
                        model.module if hasattr(model, "module") else model
                    )  # Take care of distributed/parallel training
                    model_to_save.save_pretrained(output_dir)
                    tokenizer.save_pretrained(output_dir)

                    torch.save(args, os.path.join(output_dir, "training_args.bin"))
                    logger.info("Saving model checkpoint to %s", output_dir)

                    _rotate_checkpoints(args, checkpoint_prefix)

                    torch.save(optimizer.state_dict(), os.path.join(output_dir, "optimizer.pt"))
                    torch.save(scheduler.state_dict(), os.path.join(output_dir, "scheduler.pt"))
                    logger.info("Saving optimizer and scheduler states to %s", output_dir)

            if args.max_steps > 0 and global_step > args.max_steps:
                epoch_iterator.close()
                break
        if args.max_steps > 0 and global_step > args.max_steps:
            train_iterator.close()
            break

    if args.local_rank in [-1, 0]:
        tb_writer.close()

    return global_step, tr_loss / global_step

# Evaluation of some model

def evaluate(args, model: PreTrainedModel, tokenizer: PreTrainedTokenizer, df_trn, df_val, prefix="") -> Dict:
    # Loop to handle MNLI double evaluation (matched, mis-matched)
    eval_output_dir = args.output_dir

    eval_dataset = load_and_cache_examples(args, tokenizer, df_trn, df_val, evaluate=True)
    os.makedirs(eval_output_dir, exist_ok=True)
    args.eval_batch_size = args.per_gpu_eval_batch_size * max(1, args.n_gpu)
    # Note that DistributedSampler samples randomly

    def collate(examples: List[torch.Tensor]):
        if tokenizer._pad_token is None:
            return pad_sequence(examples, batch_first=True)
        return pad_sequence(examples, batch_first=True, padding_value=tokenizer.pad_token_id)

    eval_sampler = SequentialSampler(eval_dataset)
    eval_dataloader = DataLoader(
        eval_dataset, sampler=eval_sampler, batch_size=args.eval_batch_size, collate_fn=collate, drop_last = True
    )

    # multi-gpu evaluate
    if args.n_gpu > 1:
        model = torch.nn.DataParallel(model)

    # Eval!
    logger.info("***** Running evaluation {} *****".format(prefix))
    logger.info("  Num examples = %d", len(eval_dataset))
    logger.info("  Batch size = %d", args.eval_batch_size)
    eval_loss = 0.0
    nb_eval_steps = 0
    model.eval()

    for batch in tqdm(eval_dataloader, desc="Evaluating"):
        inputs, labels = (batch, batch)
        inputs = inputs.to(args.device)
        labels = labels.to(args.device)

        with torch.no_grad():
            outputs = model(inputs, labels=labels)
            lm_loss = outputs[0]
            eval_loss += lm_loss.mean().item()
        nb_eval_steps += 1

    eval_loss = eval_loss / nb_eval_steps
    perplexity = torch.exp(torch.tensor(eval_loss))

    result = {"perplexity": perplexity}

    output_eval_file = os.path.join(eval_output_dir, prefix, "eval_results.txt")
    with open(output_eval_file, "w") as writer:
        logger.info("***** Eval results {} *****".format(prefix))
        for key in sorted(result.keys()):
            logger.info("  %s = %s", key, str(result[key]))
            writer.write("%s = %s\n" % (key, str(result[key])))

    return result

# %%
# Main runner

def main(df_trn, df_val):
    args = Args()

    if args.should_continue:
        sorted_checkpoints = _sorted_checkpoints(args)
        if len(sorted_checkpoints) == 0:
            raise ValueError("Used --should_continue but no checkpoint was found in --output_dir.")
        else:
            args.model_name_or_path = sorted_checkpoints[-1]

    if (
        os.path.exists(args.output_dir)
        and os.listdir(args.output_dir)
        and args.do_train
        and not args.overwrite_output_dir
        and not args.should_continue
    ):
        raise ValueError(
            "Output directory ({}) already exists and is not empty. Use --overwrite_output_dir to overcome.".format(
                args.output_dir
            )
        )

    # Setup CUDA, GPU & distributed training
    device = torch.device("cuda")
    args.n_gpu = torch.cuda.device_count()
    args.device = device

    # Setup logging
    logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO if args.local_rank in [-1, 0] else logging.WARN,
    )
    logger.warning(
        "Process rank: %s, device: %s, n_gpu: %s, distributed training: %s, 16-bits training: %s",
        args.local_rank,
        device,
        args.n_gpu,
        bool(args.local_rank != -1),
        args.fp16,
    )

    # Set seed
    set_seed(args)

    config = AutoConfig.from_pretrained(args.config_name, cache_dir=args.cache_dir)
    tokenizer = AutoTokenizer.from_pretrained(args.tokenizer_name, cache_dir=args.cache_dir)
    model = AutoModelWithLMHead.from_pretrained(
        args.model_name_or_path,
        from_tf=False,
        config=config,
        cache_dir=args.cache_dir,
    )
    model.to(args.device)

    logger.info("Training/evaluation parameters %s", args)

    # Training
    if args.do_train:
        train_dataset = load_and_cache_examples(args, tokenizer, df_trn, df_val, evaluate=False)

        global_step, tr_loss = train(args, train_dataset, model, tokenizer)
        logger.info(" global_step = %s, average loss = %s", global_step, tr_loss)

    # Saving best-practices: if you use save_pretrained for the model and tokenizer, you can reload them using from_pretrained()
    if args.do_train:
        # Create output directory if needed
        os.makedirs(args.output_dir, exist_ok=True)

        logger.info("Saving model checkpoint to %s", args.output_dir)
        # Save a trained model, configuration and tokenizer using `save_pretrained()`.
        # They can then be reloaded using `from_pretrained()`
        model_to_save = (
            model.module if hasattr(model, "module") else model
        )  # Take care of distributed/parallel training
        model_to_save.save_pretrained(args.output_dir)
        tokenizer.save_pretrained(args.output_dir)

        # Good practice: save your training arguments together with the trained model
        torch.save(args, os.path.join(args.output_dir, "training_args.bin"))

        # Load a trained model and vocabulary that you have fine-tuned
        model = AutoModelWithLMHead.from_pretrained(args.output_dir)
        tokenizer = AutoTokenizer.from_pretrained(args.output_dir)
        model.to(args.device)

    # Evaluation
    results = {}
    if args.do_eval and args.local_rank in [-1, 0]:
        checkpoints = [args.output_dir]
        if args.eval_all_checkpoints:
            checkpoints = list(
                os.path.dirname(c) for c in sorted(glob.glob(args.output_dir + "/**/" + WEIGHTS_NAME, recursive=True))
            )
            logging.getLogger("transformers.modeling_utils").setLevel(logging.WARN)  # Reduce logging
        logger.info("Evaluate the following checkpoints: %s", checkpoints)
        for checkpoint in checkpoints:
            global_step = checkpoint.split("-")[-1] if len(checkpoints) > 1 else ""
            prefix = checkpoint.split("/")[-1] if checkpoint.find("checkpoint") != -1 else ""

            model = AutoModelWithLMHead.from_pretrained(checkpoint)
            model.to(args.device)
            result = evaluate(args, model, tokenizer, df_trn, df_val, prefix=prefix)
            result = dict((k + "_{}".format(global_step), v) for k, v in result.items())
            results.update(result)

    return results

# %% [markdown]
# ## Run the Main Function

# %%
main(trn_df, val_df)
# Out:
# WARNING:__main__:Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1595: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/2655 [00:00<?, ?it/s]

# %%
# !python -V
# Out:
# Python 3.10.12

# %% [markdown]
# ## Load the Trained Model

# %%
tokenizer = AutoTokenizer.from_pretrained('microsoft/DialoGPT-small')
model = AutoModelWithLMHead.from_pretrained('output-small_2')

# %%
import os

# Get the current working directory


# List all files in the current working directory
files = os.listdir('output-small')

# Print the list of files
print("Files in the current working directory:")
for file in files:
    print(file)
# Out:
# Files in the current working directory:
# checkpoint-3500
# checkpoint-7000
# checkpoint-10500
# checkpoint-14000
# checkpoint-17500
# checkpoint-21000
# checkpoint-24500
# config.json
# generation_config.json
# model.safetensors
# vocab.json
# special_tokens_map.json
# training_args.bin
# tokenizer_config.json
# tokenizer.json
# merges.txt
# eval_results.txt

# %%
# Let's chat for 4 lines
for step in range(4):
    # encode the new user input, add the eos_token and return a tensor in Pytorch
    new_user_input_ids = tokenizer.encode(input(">> User:") + tokenizer.eos_token, return_tensors='pt')
    print('new_user_input_ids: ', new_user_input_ids)

    # append the new user input tokens to the chat history
    bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1) if step > 0 else new_user_input_ids
    print('bot_input_ids: ', bot_input_ids)

    # generated a response while limiting the total chat history to 1000 tokens,
    chat_history_ids = model.generate(
        bot_input_ids, max_length=200,
        pad_token_id=tokenizer.eos_token_id,
        no_repeat_ngram_size=3,
        do_sample=True,
        top_k=100,
        top_p=0.7,
        temperature=0.8
    )

    # pretty print last ouput tokens from bot
    print('chat_history_ids[:, bot_input_ids.shape[-1]:][0]: ', chat_history_ids[:, bot_input_ids.shape[-1]:][0])
    output_string = tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)
    print('output_string: ', output_string)
    print("MichaelBot: {}".format(output_string))
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# new_user_input_ids:  tensor([[31373, 50256]])
# bot_input_ids:  tensor([[31373, 50256]])
# chat_history_ids[:, bot_input_ids.shape[-1]:][0]:  tensor([15496,    13, 50256])
# output_string:  Hello.
# MichaelBot: Hello.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# new_user_input_ids:  tensor([[10919,   318,   534,  1438,    30, 50256]])
# bot_input_ids:  tensor([[31373, 50256, 15496,    13, 50256, 10919,   318,   534,  1438,    30,
#          50256]])
# chat_history_ids[:, bot_input_ids.shape[-1]:][0]:  tensor([13256,  4746,    13, 50256])
# output_string:  Michael Scott.
# MichaelBot: Michael Scott.
# >> User:ok
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# new_user_input_ids:  tensor([[  482, 50256]])
# bot_input_ids:  tensor([[31373, 50256, 15496,    13, 50256, 10919,   318,   534,  1438,    30,
#          50256, 13256,  4746,    13, 50256,   482, 50256]])
# chat_history_ids[:, bot_input_ids.shape[-1]:][0]:  tensor([    0,     0,     0,  5145,     0,     0, 13896,     0,     0, 50256])
# output_string:  !!!!!!!!!!!!
# MichaelBot: !!!!!!!!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d2939fd1d4d6> in <cell line: 2>()
#       2 for step in range(4):
#       3     # encode the new user input, add the eos_token and return a tensor in Pytorch
# ----> 4     new_user_input_ids = tokenizer.encode(input(">> User:") + tokenizer.eos_token, return_tensors='pt')
#       5     print('new_user_input_ids: ', new_user_input_ids)
#       6
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Push Model to Hugging Face

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
model.push_to_hub("michael-chat-bot")
tokenizer.push_to_hub("michael-chat-bot")

# %% [markdown]
# ## All Done!
